# %% [markdown]
# <h1>Klasifikácia kvality vína pomocou viacvrstvového perceptrónu</h1>
# <br>
# <h2>Import potrebných knižníc</h2>
# <p>Na začiatok si importujeme potrebné knižnice. V našom projekte budeme potrebovať pandas a numpy pre prácu s dátami, pre vizualizáciu dát použijeme matplotlib a seaborn, ďalej budeme potrebovať MLPClassifier (Multi-layer Perceptron classifier) čiže klasifikátor, ktorý s určitou presnosťou klasifikuje dáta do príslušných skupín. Na štandardizáciu dát použijeme StandardScaler, potom pomocou train_test_split budeme neskôr rozdeľovať dáta na trénovacie a testovacie, a na koniec si ešte importujeme classification_report na výpis výsledkov klasifikácie.</p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns

from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# <h2>Príprava datasetu</h2>
# <p>Pomocou read_csv si načítame príslušný dataset do padnas dataframeu.</p>

# %%
#načítanie datasetu
dataset = pd.read_csv("../NS2021_Dicer/wine-dataset.csv")

# %% [markdown]
# <p>Ako môžeme vidieť dataset obsahuje nasledujúce parametre:</p>
# <p><b>type</b>: typ vína (biele , červené)</p>
# <p><b>fixed acidity</b>: stála kyslosť</p>
# <p><b>volatile acidity</b>: prchavá kyslosť</p>
# <p><b>citric acid</b>: kyselina citrónová</p>
# <p><b>residual sugar</b>: zvyškový cukor</p>
# <p><b>chlorides</b>: chloridy</p>
# <p><b>free sulfur dioxide</b>: voľný oxid siričitý</p>
# <p><b>total sulfur dioxide</b>: celkový oxid siričitý</p>
# <p><b>density</b>: hustota</p>
# <p><b>pH</b>: pH (kyslosť)</p>
# <p><b>sulphates</b>: sírany</p>
# <p><b>alcohol</b>: alkohol</p>
# <p><b>quality</b>: kvalita vína</p>

# %%
dataset
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
#použijeme describe na výpis štatistiky
dataset['quality'].describe()
# Out:
# count    6497.000000
# mean        5.818378
# std         0.873255
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         9.000000
# Name: quality, dtype: float64

# %% [markdown]
# <p>Kvalita vín je ohodnotená na stupnici 0 až 10. Najlepšie vína sú v datasete ohodnotené deviatimi bodmi a najhoršie tromi. Keďže takéto rozdelenie nie je pre nás ideálne, rozdelíme si ich do troch kategórií:</p>
# <p><b>nízka kvalita (0)</b> , <b>stredná kvalita (1)</b> , <b>vysoká kvalita (2)</b></p>

# %%
#vína s hodnotením 3-5 zaradíme do -> nízka kvalita
#vína s hodnotením 6-7 zaradíme do -> stredná kvalita
#vína s hodnotením 8-9 zaradíme do -> vysoká kvalita
bins= [0, 5.5, 7.5, 10]

#nízka kvalita (0) , stredná kvalita (1) , vysoká kvalita (2)
labels = [0, 1, 2] 

#stĺpec quality prerozdelíme do kategórií 0, 1, 2
dataset['quality'] = pd.cut(dataset['quality'], bins=bins, labels=labels)

# %% [markdown]
# <p>Aby sme mali dataset pripravený na klasifikáciu, musíme ešte doplniť chýbajúce hodnoty pomocou <b>fillna()</b>, takže tieto hodnoty vyplníme priemerom príslušného stĺpcu.<p>

# %%
#nahradenie chýbajúcich hodnôt priemerom stĺpca
dst = dataset.fillna(dataset.mean())
#výpis prvých 10 prvkov
dst.head(10)
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
# 5  white            8.1              0.28         0.40             6.9
# 6  white            6.2              0.32         0.16             7.0
# 7  white            7.0              0.27         0.36            20.7
# 8  white            6.3              0.30         0.34             1.6
# 9  white            8.1              0.22         0.43             1.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# ...

# %% [markdown]
# <h2>Porozumenie dátam</h2>

# %% [markdown]
# <p>Pri použití funkcie <b>describe()</b> môžeme vidieť štatistické údaje datasetu, ako napríklad <b>count</b> (počet prvkov), <b>mean</b> (priemer), <b>std</b> (štandardná odchýlka), <b>min</b> (minimálna hodnota), <b>max</b> (maximálna hodnota). Vďaka tomu môžeme vidieť v akom rozmedzí sa dáta v príslušných stĺpcoch pohybujú.</p>

# %%
#použijeme describe na výpis štatistiky
dst.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.295751          0.164548     0.145231        4.757392
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035031            17.749400             56.521855     0.002999
# ...

# %% [markdown]
# <p>Zaujímavé poznatky môžeme získať rozdelením parametrov podľa kvality vína. Preto si pomocou funkcie <b>groupby()</b> zoskupíme dáta podľa kvality vína a následne parametre pomocou <b>mean()</b> zpriemerujeme. Môžeme pozorovať určité odlišnosti parametrov vzhľadom na kvalitu vína. Napríklad môžeme vyčítať že čím viac alkoholu víno obsahuje, tým je väčšia pravdepodobnosť že bude mať vyššiu kvalitu. Naopak, čím viac chloridov obsahuje víno tým je väčšia pravdepodobnosť že bude dosahovať nižšiu kvalitu.</p>

# %%
#zobrazíme premiery parametrov podľa kvality
means = dst.groupby('quality').mean()
means
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 0             7.332040          0.397506     0.304182        5.646225
# 1             7.164551          0.306938     0.326809        5.326102
# 2             6.855134          0.291187     0.333889        5.351010
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 0         0.064412            29.480495            119.277055  0.995756
# 1         0.051717            30.960281            113.505747  0.994164
# 2         0.040778            34.505051            117.479798  0.992487
#
#                pH  sulphates    alcohol
# quality
# 0        3.214398   0.524225   9.873544
# 1        3.220478   0.536478  10.807612
# 2        3.225354   0.511313  11.691414

# %% [markdown]
# <h2>Vizualizácia dát</h2>

# %% [markdown]
# <p>Ako prvé si vizualizujeme rozdelenie vín podľa kvality. Ako môžeme videť najmenej vín (len okolo 200) spadá do množiny <b>2</b> (vysoká kvalita), najviac (okolo 3800) do množiny <b>1</b>  (stredná kvalita) a okolo 2400 vín patrí do množiny <b>0</b>  (nízka kvalita). Na vizualizáciu môžeme použit histogram s knižnice seaborn.</p>

# %%
#graf početnosti stĺpca quality
ax = sns.histplot(data=dst['quality'])
ax.set_xticks([0,1,2])

# %% [markdown]
# <p>Koreláciu parametrov môžeme vizualizovať pomocou teplotnej mapy - heatmap v knižnici seaborn. Teplotná mapa je grafické zobrazenie dát, v ktorom je každá hodnota reprezentovaná farbou určitého spojitého farebného spektra. Farba určuje vzťah medzi príslušnými parametrami. Čím je farba svetlejšia, tým majú parametre silnejší vzťah. Naopak, čím je farba tmavšia, tým je vzťah slabší. Podľa grafu môžeme vidieť že silný vzťah majú napríklad parametre "<b>free sulfur dioxide</b>" a "<b>total sulfur dioxide</b>", naopak slabý vzťah majú napríklad parametre "<b>alcohol</b>" a "<b>density</b>". Svetlé polia na diagonále predstavujú vlastný vzťah parametra, preto sú logicky najsvetlejšie.</p>

# %%
#graf teplotnej mapy korelácie parametrov
corr = dst.corr()
sns.heatmap(corr, xticklabels = corr.columns.values,yticklabels=corr.columns.values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <p>Vizualizáciu rozdelenia zpriemerovaných parametrov podľa kvality vína, ktorú sme si už prichystali do dataframeu vyššie, teraz môžeme zrealizovať pomocou matplotlib subplots. Môžeme vidieť aké priemerné hodnoty dosahujú parametre v ktorej množine kvality. Z grafov môžeme ľahko vyčítať rôzne informácie. Napríklad že <b>kvalitnejšie</b> vína majú zvyčajne nižšiu <b>stálu kyslosť</b> (fixed acidity), nižšiu <b>prchavú kyslosť</b> (volatile acidity), menej <b>chloridov</b> (chlorides), menšiu <b>hustotu</b> (density), viac <b>kyseliny citrónoovej</b> (citric acid), viac <b>pH</b> (kyslosť), viac <b>alkoholu</b> (alcohol), viac <b>voľného oxidu siričitého</b> (free sulfur dioxide). </p>

# %%
#grafy priemerov parametrov podľa kvality
fig, axs = plt.subplots(4,3)
fig.set_figheight(18)
fig.set_figwidth(18)

plt.setp(axs,xticks=[0, 1, 2])

axs[0,0].plot(np.array(means["fixed acidity"]),'bo',linestyle='--',label="fixed acidity")
axs[0,0].legend(loc="upper right")
axs[0,0].axvline(x=0,color="r")
axs[0,0].axvline(x=1,color="r")
axs[0,0].axvline(x=2,color="r")
axs[0,0].set_xlabel('quality')
axs[0,0].set_ylabel('fixed acidity - mean')
axs[0,0].set

axs[0,1].plot(np.array(means["volatile acidity"]),'bo',linestyle='--',label="volatile acidity")
axs[0,1].legend(loc="upper right")
axs[0,1].axvline(x=0,color="r")
axs[0,1].axvline(x=1,color="r")
axs[0,1].axvline(x=2,color="r")
axs[0,1].set_xlabel('quality')
axs[0,1].set_ylabel('volatile acidity - mean')

axs[0,2].plot(np.array(means["citric acid"]),'bo',linestyle='--',label="citric acid")
axs[0,2].legend(loc="lower right")
axs[0,2].axvline(x=0,color="r")
axs[0,2].axvline(x=1,color="r")
axs[0,2].axvline(x=2,color="r")
axs[0,2].set_xlabel('quality')
axs[0,2].set_ylabel('citric acid - mean')

axs[1,0].plot(np.array(means["residual sugar"]),'bo',linestyle='--',label="residual sugar")
axs[1,0].legend(loc="upper right")
axs[1,0].axvline(x=0,color="r")
axs[1,0].axvline(x=1,color="r")
axs[1,0].axvline(x=2,color="r")
axs[1,0].set_xlabel('quality')
axs[1,0].set_ylabel('residual sugar - mean')

axs[1,1].plot(np.array(means["chlorides"]),'bo',linestyle='--',label="chlorides")
axs[1,1].legend(loc="upper right")
axs[1,1].axvline(x=0,color="r")
axs[1,1].axvline(x=1,color="r")
axs[1,1].axvline(x=2,color="r")
axs[1,1].set_xlabel('quality')
axs[1,1].set_ylabel('hlorides - mean')

axs[1,2].plot(np.array(means["free sulfur dioxide"]),'bo',linestyle='--',label="free sulfur dioxide")
axs[1,2].legend(loc="upper left")
axs[1,2].axvline(x=0,color="r")
axs[1,2].axvline(x=1,color="r")
axs[1,2].axvline(x=2,color="r")
axs[1,2].set_xlabel('quality')
axs[1,2].set_ylabel('free sulfur dioxide - mean')

axs[2,0].plot(np.array(means["total sulfur dioxide"]),'bo',linestyle='--',label="total sulfur dioxide")
axs[2,0].legend(loc="upper right")
axs[2,0].axvline(x=0,color="r")
axs[2,0].axvline(x=1,color="r")
axs[2,0].axvline(x=2,color="r")
axs[2,0].set_xlabel('quality')
axs[2,0].set_ylabel('total sulfur dioxide - mean')

axs[2,1].plot(np.array(means["density"]),'bo',linestyle='--',label="density")
axs[2,1].legend(loc="upper right")
axs[2,1].axvline(x=0,color="r")
axs[2,1].axvline(x=1,color="r")
axs[2,1].axvline(x=2,color="r")
axs[2,1].set_xlabel('quality')
axs[2,1].set_ylabel('density - mean')

axs[2,2].plot(np.array(means["pH"]),'bo',linestyle='--',label="pH")
axs[2,2].legend(loc="upper left")
axs[2,2].axvline(x=0,color="r")
axs[2,2].axvline(x=1,color="r")
axs[2,2].axvline(x=2,color="r")
axs[2,2].set_xlabel('quality')
axs[2,2].set_ylabel('pH - mean')

axs[3,0].plot(np.array(means["sulphates"]),'bo',linestyle='--',label="sulphates")
axs[3,0].legend(loc="upper right")
axs[3,0].axvline(x=0,color="r")
axs[3,0].axvline(x=1,color="r")
axs[3,0].axvline(x=2,color="r")
axs[3,0].set_xlabel('quality')
axs[3,0].set_ylabel('sulphates - mean')

axs[3,1].plot(np.array(means["alcohol"]),'bo',linestyle='--',label="alcohol")
axs[3,1].legend(loc="upper left")
axs[3,1].axvline(x=0,color="r")
axs[3,1].axvline(x=1,color="r")
axs[3,1].axvline(x=2,color="r")
axs[3,1].set_xlabel('quality')
axs[3,1].set_ylabel('alcohol - mean')
# Out:
# Text(0, 0.5, 'alcohol - mean')

# %% [markdown]
# <h2>Aplikovanie viacvrstvového perceptrónu</h2>
# <p>Viacvrstvový perceptrón je neurónová sieť, ktorá je tvorená vzájomne prepojenými neurónmi, ktoré sú
# usporiadané do viacerých vrstiev. Ak každý neurón jednej vrstvy vysiela signály na každý neurón nasledujúcej vrstvy
# hovoríme o <b>dopredných neurónových sieťach</b>. U dopredných sietí neexistujú spojenia medzi neurónmi tej istej vrstvy, ani medzi neurónmi vzdialených vrstiev. Spojené sú len neuróny susedných vrstiev a to tak, že každý neurón n-tej vrstvy je spojený s každým neurónom n+1-tej vrstvy. </p>
# <p>Táto sieť sa pri učení opiera o pravidlo, ktoré nesie názov <b>metóda spätného šírenia chýb</b>. Sieť s ktorou pracujeme má vstupnú vrstvu, tri skryté vrstvy a výstupnú vrstvu. Prepojenia vedú smerom od nižšej vrstvy k vyššej. Približnú schému našej siete môžeme vidieť na obrázku nižšie, pričom počet neurónov na vstupnej vrstve sa rovná počtu vstupných parametrov (11), a v každej skrytej vrstve sa nachádza 100 neurónov, pretože tak sme si to zadefinovali v MLPClassifier triede -> hidden_layer_sizes=(100,100,100).
# </p>
# <img src="./images/mlp.png"></img>
# <p><b><i>Viacvrstvový perceptrón</i></b> sme si vybrali s toho dôvodu, že problematika ktorou sa zaoberáme <b>nie je lineárne separovateľná</b>, čiže jednoduchý perceptrón na klasifikáciu nestačí. Viacvrstvový perceptrón vie klasifikovať aj problémy ktoré nie sú lineárne separovateľné, preto sa takáto sieť na tento dataset hodí.</p><br>
# <b>Algoritmus Back-propagation (metóda spätného šírenia chýb)</b>
# <p>Už názov pravidla podľa ktorého sa bude naša sieť učiť nám našepkáva, že budeme
# počítať akúsi chybu a tú asi budeme propagovať a to nie v smere dopredu ale späť. Pozor,
# nejde o spätné šírenie signálu ale spätné šírenie chyby.Metóda spätného šírenia chyby alebo hovoríme tiež algoritmus back-propagation je najpoužívanejšia metóda pre učenie dopredných viacvrstvových neurónových sietí a používa sa až v 80% aplikácií.</p>
# <p>Princíp práce back-propagation si môžeme ukázať na príklade:</p><br>
# Výpočet výstupu pre tretí neurón prvej vrstvy:
# <img src="./images/bp1.PNG"></img>
# Výpočet výstupu pre prvý neurón druhej vrstvy:
# <img src="./images/bp2.PNG"></img>
# Výpočet výstupu pre tretiu vrstvu:
# <img src="./images/bp3.PNG"></img>
# Šírenie chyby:
# <img src="./images/bp4.PNG"></img>
# <p>Môžeme vidieť že pri učení siete sa pre každý neurón násobia váhy neurónov z predchádzajúcej vrstvy a výstupy neurónov prechádzajúcej vrstvy, ktoré sa nakoniec spočítajú + sa pripočíta bias. Keď získame celkový výstup siete, porovnáme ho s očakávaným výstupom. Ak sú tieto hodnoty totožné, môže sa prejsť na ďalší príklad z tréningovej množiny a
# opakovať tento postup. Ak nie, odčítame získaný výstup od očakávaného, čím dostaneme tzv. chybový signál, ktorý označujeme delta, a ktorý budeme šíriť po sieti späť. Pomocou chybového signálu môžeme modifikovať pôvodne váhy pre každý neurón, a to spôsobí že sa postupne váhy upravia na očakávanú podobu.</p>
#
# <b>Aktivačná funkcia</b>
# <p>Aktivačná funkcia nám slúži na generovanie akčného potenciálu a prináša nelineárnosť do celého systému.</p><br>
# <b><i>ReLu (Rectified linear unit)</i></b>
# <img src="./images/relu.png"></img>
# <p>ReLu ( f(x) = max(0, x) ) je v súčasnosti najpoužívanejšou aktivačnou funkciou hlavne v hlbokých
# učiacich sa sieťach. Jedným z hlavných nevýhod sigmoid funkcie a hyperbolického tangensu je, že sú relatívne ploché na väčšine svojho definičného oboru. Relatívna plochosť
# znamená malé hodnoty derivácií, čo spôsobuje ťažkosti pri vylepšovaní váh hlavne v
# sieťach s mnohými vrstvami. ReLu týmto problémom netrpí, keďže jej derivácia na
# intervale (0,∞) je 1.</p><br>
# <p>S pomedzi iných aktivačných funkcií najlepšie obstála Retifikovaná lineárna jednotka (ReLu), preto sme ReLu zvolili za aktivačnú funkciu v našej neurónovej sieti. Výsledky presnosti siete pri rôznych aktivačných funkciách:</p>
# <ul>
#     <li><b>tanh</b>: accuracy score ≈ 71.71 %</li>
#     <li><b>relu</b>: accuracy score ≈ 80.21 %</li>
#     <li><b>logistic</b>: accuracy score ≈ 70.96 %</li>
#     <li><b>identity</b>: accuracy score ≈ 71.07 %</li>
# </ul><br>
# <b>Rozdelenie dát na trénovacie a testovacie</b>
# <p>Ako prvé sme si do premennej x vložili všetky stĺpce datasetu okrem stĺpcov <b>type</b> a <b>quality</b>. Vylúčenie stĺpcov sme zabezpečili pomocou funckie <b>drop()</b>. Do premennej y sme si vybrali iba stĺpec <b>quality</b>. Potom sme pre x použili <b>StandardScaler</b> a jeho funkciu <b>fit_transform()</b>, ktorá štandardizuje a prispôsobí dáta, a transofmuje ich. Potom pomocou funkcie <b>train_test_split()</b> ktorú sme si importovali, vieme rozdeliť dáta na náhodné trénovacie a testovacie podmnožiny. Ako parametre funkcie sme použili premenné <b>x</b> a <b>y</b>, a ako ďalší parameter sme určili <b>test_size</b> ktorý sme nastavili na 0.2, čiže ako testovacie dáta sa zoberie 20% dát z datasetu. Tento pomer sme si zvolili po odskúšaní rôznych kombinácií rozdelenia. Následne sme skonštatovali že tento pomer je vyhovujúci príslušnému datasetu. Parameter <b>random_state</b> sme si nastavili na náhodné číslo. Random_state ovláda premiešanie použité na údaje pred rozdelením.</p>

# %%
#vyhodím stĺpce type a quality a vložím ich do x
x = dst.drop(columns=['type','quality'])

#zoberiem stĺpec quality a vložím ho do y
y = dst['quality']

#štandardizácia a prispôsobenie dát
sc = StandardScaler()
x = sc.fit_transform(x)

#rozdelenie dát na náhodné trénovacie a testovacie podmnožiny
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.2,random_state=42)

# %% [markdown]
# <b>Vytvorenie inštancie triedy MLPClassifier</b>
# <p>Inštanciu triedy MLPClassifier (klasifikátor imoprtovaný z knižnice sklearn) sme si vložili do premennej mlp. Na prispôsobenie klasifikátora si do konštruktora triedy musíme zadať niekoľko parametrov:</p>
# <ul>
#     <li><b>hidden_layer_sizes=(100,100,100)</b> -> neurónová sieť bude mať 3 skryté vrstvy, každá po 100 neurónoch</li>
#     <li><b>max_iter=500</b> -> maximálny počet iterácií je 500</li>
#     <li><b>early_stopping=True</b> -> zabezpečí to že sa trénovanie zastaví keď sa presnosť učenia nezlepšuje</li>
#     <li><b>activation='relu'</b> -> aplikovanie aktivačnej funkcie ReLu</li>
#     <li><b>alpha=0.007</b> -> regularizačný parameter</li>
#     <li><b>solver='adam'</b> -> solver pre optimalizáciu váh (adam dosahuje najlepšie výsledky)</li>
#     <li><b>learning_rate='adaptive'</b> -> adaptívna rýchlosť učenia</li>
#     <li><b>verbose = True</b> -> zabezpečí výpis iterácií , loss a validation score</li>
# </ul>

# %%
#vytvorenie inštancie MLPClassifier a nastavenie potrebných parametrov
mlp = MLPClassifier(hidden_layer_sizes=(100,100,100),
                    max_iter=500,
                    early_stopping=True,
                    activation='relu',
                    alpha=0.007,
                    solver='adam',
                    learning_rate='adaptive',
                    verbose = True)

# %% [markdown]
# <b>Proces učenia siete</b>
# <p>To zabezpečíme pomocou funkcie <b>fit()</b>, kde ako parametre idú trénovacie množiny <b>x_train</b> a <b>y_train</b>. Pri výpise vidíme, že sa učenie zastaví skôr ako dosiahne maximálny počet iterácií (max_iter=500). To je spôsobené tým že bol nastavený parameter <b>early_stopping</b> na True, čiže proces bol zastavený kvôli tomu že sa už presnosť nezlepšovala.</p>

# %%
#trénovanie siete
history = mlp.fit(x_train,y_train)
# Out:
# Iteration 1, loss = 0.81526644
# Validation score: 0.700000
# Iteration 2, loss = 0.68138098
# Validation score: 0.746154
# Iteration 3, loss = 0.64491540
# Validation score: 0.736538
# Iteration 4, loss = 0.63037310
# Validation score: 0.769231
# Iteration 5, loss = 0.62478370
# Validation score: 0.763462
# Iteration 6, loss = 0.61050590
# Validation score: 0.773077
# Iteration 7, loss = 0.60340244
# Validation score: 0.755769
# Iteration 8, loss = 0.59542839
# Validation score: 0.767308
# Iteration 9, loss = 0.58674282
# Validation score: 0.763462
# Iteration 10, loss = 0.58220518
# Validation score: 0.765385
# Iteration 11, loss = 0.57855889
# Validation score: 0.769231
# Iteration 12, loss = 0.57106105
# Validation score: 0.763462
# Iteration 13, loss = 0.56232566
# Validation score: 0.778846
# Iteration 14, loss = 0.55724341
# Validation score: 0.771154
# Iteration 15, loss = 0.55052682
# Validation score: 0.771154
# Iteration 16, loss = 0.54507408
# Validation score: 0.769231
# ...

# %% [markdown]
# <h2>Výsledky</h2>
# <p>To zbehnutí učenia siete sme si vypísali "accuracy score", čiže presnosť našej neurónovej siete. Presnosť viacvrstvového perceptrónu dosahuje pri klasifikácii tohoto datasetu približne 80 % (≈ 80 %), takže klasifikácia nie je dokonalá. Keďže máme dataset z reálneho sveta so skutočnými parametrami, klasifikácia je značne náročnejšia, preto sieť dosahuje určitú chybovosť, čo je v poriadku, pretože neurónová sieť založená na reálnych dátach málokedy dosahuje presnosť ktorá sa približuje k dokonalosti.</p>

# %%
#výpis presnosti
print("MLP accuracy score:",mlp.score(x_train,y_train)*100,"%")
# Out:
# MLP accuracy score: 81.00827400423321 %

# %% [markdown]
# <p>Metóda <b>predict()</b> nám zabezpečí predikovanie, kde ako parameter zadávame testovaciu množinu <b>x_test</b>. Pomocou importovanej funkcie <b>classification_report()</b> možeme vidieť podrobnejší výpis klasifikácie, kde ako prvý parameter ide testovacia množina <b>y_test</b> a ako druhý predikicia <b>pred_mlp</b>.</p>

# %%
#podrobnejší výpis klasifikácie
pred_mlp= mlp.predict(x_test)
print(classification_report(y_test, pred_mlp))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.72      0.72       468
#            1       0.81      0.82      0.82       800
#            2       0.40      0.06      0.11        32
#
#     accuracy                           0.77      1300
#    macro avg       0.64      0.54      0.55      1300
# weighted avg       0.76      0.77      0.76      1300
# 3103    1
# 1419    1
# 4761    1
# 4690    1
# 4032    0
#        ..
# 889     1
# 2850    0
# 4917    1
# 5198    1
# 5643    1
# Name: quality, Length: 1300, dtype: category
# Categories (3, int64): [0 < 1 < 2]

# %% [markdown]
# <p>Pomocou poľa <b>validation_scores_</b> ktoré sa naplnilo počas procesu učenia môžeme vizualizovať presnosť viacvrstvového perceptrónu pri kalsifikácii. Graf zobrazíme pomocou knižnice matplotlib. Na x-ovej osi môžeme vidieť počet iterácií a na y-ovej osi sa nachádza presnosť. Vidíme že priebeh nebol úplne hladký, ale presnosť postupne narastala. Graf končí pri itérácií kde sa už presnosť moc nezlepšovala (spôsobené early_stopping = True).</p>

# %%
#graf presnosti
plt.plot(history.validation_scores_)
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# <p>Nakoniec pomocou pola <b>loss_curve_</b> ktoré sa tiež naplnilo počas priebehu učenia vizualizujeme chybu siete v čase. Na x-ovej osi sa nachádza počet iterácií a na y-ovej osi sa nachádza chyba. Môžeme vidieť že chyba postupne klesala, čiže sieť postupne zlepšovala svoju presnosť.</p>

# %%
#graf chyby
plt.plot(history.loss_curve_)
plt.xlabel("Iteration")
plt.ylabel("Error")
# Out:
# Text(0, 0.5, 'Error')
